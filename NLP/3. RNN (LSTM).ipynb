# %% [markdown]
# # Single Layer LSTM
# - https://www.youtube.com/watch?v=BSpXCRTOLJA&ab_channel=sentdex

# %%
import tensorflow_datasets as tfds

# Download the subword encoded pretokenized dataset
dataset, info = tfds.load('imdb_reviews/subwords8k', with_info=True, as_supervised=True)

# Get the tokenizer
tokenizer = info.features['text'].encoder
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incompleteBC4KJP/imdb_reviews-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incompleteBC4KJP/imdb_reviews-test.tfrecord*…
# Generating unsupervised examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0.incompleteBC4KJP/imdb_reviews-unsupervised.t…
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/subwords8k/1.0.0. Subsequent calls will reuse this data.

# %%
print(dataset)
# Out:
# {Split('train'): <_PrefetchDataset element_spec=(TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>, Split('test'): <_PrefetchDataset element_spec=(TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>, Split('unsupervised'): <_PrefetchDataset element_spec=(TensorSpec(shape=(None,), dtype=tf.int64, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>}

# %%
#cetak dataset
a=None
for data in dataset["train"].take(5):
    print("Tokenya: ",data[0].numpy())
    print("Decodenya: ",tokenizer.decode(data[0].numpy()))
    print("Labelnya: ",data[1].numpy())
    print()
# Out:
# Tokenya:  [  62   18   41  604  927   65    3  644 7968   21   35 5096   36   11
#    43 2948 5240  102   50  681 7862 1244    3 3266   29  122  640    2
#    26   14  279  438   35   79  349  384   11 1991    3  492   79  122
#   188  117   33 4047 4531   14   65 7968    8 1819 3947    3   62   27
#     9   41  577 5044 2629 2552 7193 7961 3642    3   19  107 3903  225
#    85  198   72    1 1512  738 2347  102 6245    8   85  308   79 6936
#  7961   23 4981 8044    3 6429 7961 1141 1335 1848 4848   55 3601 4217
#  8050    2    5   59 3831 1484 8040 7974  174 5773   22 5240  102   18
#   247   26    4 3903 1612 3902  291   11    4   27   13   18 4092 4008
#  7961    6  119  213 2774    3   12  258 2306   13   91   29  171   52
#   229    2 1245 5790  995 7968    8   52 2948 5240 8039 7968    8   74
#  1249    3   12  117 2438 1369  192   39 7975]
# Decodenya:  This was an absolutely terrible movie. Don't be lured in by Christopher Walken or Michael Ironside. Both are great actors, but this must simply be their worst role in history. Even their great acting could not redeem this movie's ridiculous storyline. This movie is an early nineties US propaganda piece. The most pathetic scenes were those when the Columbian rebels were making their cases for revolutions. Maria Conchita Alonso appeared phony, and her pseudo-love affair with Walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning. I am disappointed that there are movies like this, ruining actor's like Christopher Walken's good name. I could barely sit through it.
# Labelnya:  0
#
# Tokenya:  [  12   31   93  867    7 1256 6585 7961  421  365    2   26   14    9
#   988 1089    7    4 6728    6  276 5760 2587    2   81 6118 8029    2
#   139 1892 7961    5 5402  246   25    1 1771  350    5  369   56 5397
#   102    4 2547    3 4001   25   14 7822  209   12 3531 6585 7961   99
#     1   32   18 4762    3   19  184 3223   18 5855 1045    3 4232 3337
#    64 1347    5 1190    3 4459    8  614    7 3129    2   26   22   84
#  7020    6   71   18 4924 1160  161   50 2265    3   12 3983    2   12
#   264   31 2545  261    6    1   66    2   26  131  393    1 5846    6
#    15    5  473   56  614    7 1470    6  116  285 4755 2088 7961  273
#   119  213 3414 7961   23  332 1019    3   12 7667  505   14   32   44
#   208 7975]
# Decodenya:  I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.
# Labelnya:  0
#
# Tokenya:  [ 636  102 4714    8    1 4333    4 4135   47 1325 1174 1139    8   11
#     4 2402 1878    2    5 5619 4513    5 6872 5063 2290 7961  257 1779
#   695   20   53  278  382    7  374  221   10   16   10   17  128  288
#    25 2259   95    4 1325 1174  542 1923    1  121    6 5217  412 6696
#     2 5496 1459  102    7 1120 2098 1272    4  957  767 8037   28 7042
#     4  957  767 8037 1705    5    7  413 3439    1 5758 2522    2  144
#  2574 7605    8 2339 3212   34   15   61   25    1 6285 7961   23 3224
#     6    1 1818 4442   10   16   10   17 3281   78 7880 3299 6659   34
#    13 1314   25    1 7177  748    6    1 6135 7961  421    1 4255  136
#  2133  735 3093 7961 4564    3  745    3  636  102    5 3981 1780    7
#    31 4086  102 5217  412 5244   23 4410 2264    2    1 7177 4277 7961
#    23    1  405 5287 7961 3543 8045   24   10   16   10   17 7177 1942
#    35 5202   40   23    4 3021 3182 7961 1340  432  831    6 1779 2932
#   157   22   14 6973 7961  396    2  317    2    7 3977   49  155  716
#    11 4326  447 7975]
# Decodenya:  Mann photographs the Alberta Rocky Mountains in a superb fashion, and Jimmy Stewart and Walter Brennan give enjoyable performances as they always seem to do. <br /><br />But come on Hollywood - a Mountie telling the people of Dawson City, Yukon to elect themselves a marshal (yes a marshal!) and to enforce the law themselves, then gunfighters battling it out on the streets for control of the town? <br /><br />Nothing even remotely resembling that happened on the Canadian side of the border during the Klondike gold rush. Mr. Mann and company appear to have mistaken Dawson City for Deadwood, the Canadian North for the American Wild West.<br /><br />Canadian viewers be prepared for a Reefer Madness type of enjoyable howl with this ludicrous plot, or, to shake your head in disgust.
# Labelnya:  0
#
# Tokenya:  [  62    9    1  312    6   32   23    4 7809   47 7513 7961 1309 6971
#  7961   72    1  470    6    1  386   83  186 5082   22  116  285 2924
#    20   37 7117  228   94    4  301 1579 7974 5403 7961    5 2211  654
#    23    4  533    6 4916    3 6223  455  695   48  805  127    5 7627
#    20 5111   28   20 5995   58 5766   64 4682    1  184 3740    3  173
#    29   84 5302 1031    7 4038    2   84 6338 3419 8044    2   56    4
#  1892 7961    5 5270 7961  913 5340 7961  192  698 1951  219   44  116
#   883    3  133  381   32   11  242  471    5   45   13 2064    1 4642
#  7961   15 5809 8029 7975]
# Decodenya:  This is the kind of film for a snowy Sunday afternoon when the rest of the world can go ahead with its own business as you descend into a big arm-chair and mellow for a couple of hours. Wonderful performances from Cher and Nicolas Cage (as always) gently row the plot along. There are no rapids to cross, no dangerous waters, just a warm and witty paddle through New York life at its best. A family film in every sense and one that deserves the praise it received.
# Labelnya:  1
#
# Tokenya:  [ 249  929   31 2699  104    2   51    1  707   13  186 7141 7961   11
#    14   32   29 1115  604 2766 3816  449    3   19  184   67  864  410
#     1 6257 4050  203   47    6    1 1110  763 3665 8040    3  324  571
#    29  268   53  239    7   35 4402  104    2   26   72  484   38 1039
#    54   29 1790    2   53  544    1 4402  478    6    4 4114 7961  570
#   212 1158    3  134    1  771  611    4  172   81 2310   28  103  180
#    51   35   55 7886   44   14  595 5904  183  144  265   76    1 7845
#    49    7 4402   49   30  461  583 7975]
# Decodenya:  As others have mentioned, all the women that go nude in this film are mostly absolutely gorgeous. The plot very ably shows the hypocrisy of the female libido. When men are around they want to be pursued, but when no "men" are around, they become the pursuers of a 14 year old boy. And the boy becomes a man really fast (we should all be so lucky at this age!). He then gets up the courage to pursue his true love.
# Labelnya:  1

# %% [markdown]
# ## Prepare Dataset

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 256

# Get the train and test splits
train_data, test_data = dataset['train'], dataset['test'], 

# Shuffle the training data
train_dataset = train_data.shuffle(BUFFER_SIZE)

# Batch and pad the datasets to the maximum length of the sequences
train_dataset = train_dataset.padded_batch(BATCH_SIZE)
test_dataset = test_data.padded_batch(BATCH_SIZE)

# %% [markdown]
# ## Buid and train the model

# %%
import tensorflow as tf

# Hyperparameters
embedding_dim = 64
lstm_dim = 64
dense_dim = 64

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, embedding_dim),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_dim)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          523840
#
#  bidirectional (Bidirectiona  (None, 128)              66048
#  l)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 598,209
# Trainable params: 598,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set the training parameters
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
NUM_EPOCHS = 10

history = model.fit(train_dataset, epochs=NUM_EPOCHS, validation_data=test_dataset)
# Out:
# Epoch 1/10
# 98/98 [==============================] - 47s 376ms/step - loss: 0.5316 - accuracy: 0.7103 - val_loss: 0.3796 - val_accuracy: 0.8417
# Epoch 2/10
# 98/98 [==============================] - 31s 320ms/step - loss: 0.3701 - accuracy: 0.8459 - val_loss: 0.5591 - val_accuracy: 0.7065
# Epoch 3/10
# 98/98 [==============================] - 27s 269ms/step - loss: 0.2937 - accuracy: 0.8835 - val_loss: 0.3784 - val_accuracy: 0.8479
# Epoch 4/10
# 98/98 [==============================] - 26s 266ms/step - loss: 0.2116 - accuracy: 0.9248 - val_loss: 0.4116 - val_accuracy: 0.8450
# Epoch 5/10
# 98/98 [==============================] - 25s 251ms/step - loss: 0.1721 - accuracy: 0.9415 - val_loss: 0.4376 - val_accuracy: 0.8556
# Epoch 6/10
# 98/98 [==============================] - 24s 239ms/step - loss: 0.1576 - accuracy: 0.9458 - val_loss: 0.4364 - val_accuracy: 0.8345
# Epoch 7/10
# 98/98 [==============================] - 22s 224ms/step - loss: 0.1465 - accuracy: 0.9485 - val_loss: 0.4426 - val_accuracy: 0.8355
# Epoch 8/10
# 98/98 [==============================] - 27s 274ms/step - loss: 0.1329 - accuracy: 0.9549 - val_loss: 0.4827 - val_accuracy: 0.8484
# Epoch 9/10
# 98/98 [==============================] - 22s 220ms/step - loss: 0.1781 - accuracy: 0.9354 - val_loss: 0.4789 - val_accuracy: 0.8296
# Epoch 10/10
# 98/98 [==============================] - 23s 234ms/step - loss: 0.1032 - accuracy: 0.9668 - val_loss: 0.5088 - val_accuracy: 0.8401

# %% [markdown]
# ## Plot The Result

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # MultiLayer RNN/LSTM

# %%
import tensorflow_datasets as tfds

# Download the subword encoded pretokenized dataset
dataset, info = tfds.load('imdb_reviews/subwords8k', with_info=True, as_supervised=True)

# Get the tokenizer
tokenizer = info.features['text'].encoder
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 256

# Get the train and test splits
train_data, test_data = dataset['train'], dataset['test'], 

# Shuffle the training data
train_dataset = train_data.shuffle(BUFFER_SIZE)

# Batch and pad the datasets to the maximum length of the sequences
train_dataset = train_dataset.padded_batch(BATCH_SIZE)
test_dataset = test_data.padded_batch(BATCH_SIZE)

# %%
import tensorflow as tf
import numpy as np

# Hyperparameters
batch_size = 1
timesteps = 20
features = 16
lstm_dim = 8

print(f'batch_size: {batch_size}')
print(f'timesteps (sequence length): {timesteps}')
print(f'features (embedding size): {features}')
print(f'lstm output units: {lstm_dim}')

# Define array input with random values
random_input = np.random.rand(batch_size,timesteps,features)
print(f'shape of input array: {random_input.shape}')

# Define LSTM that returns a single output
lstm = tf.keras.layers.LSTM(lstm_dim)
result = lstm(random_input)
print(f'shape of lstm output(return_sequences=False): {result.shape}')

# Define LSTM that returns a sequence
lstm_rs = tf.keras.layers.LSTM(lstm_dim, return_sequences=True)
result = lstm_rs(random_input)
print(f'shape of lstm output(return_sequences=True): {result.shape}')
# Out:
# batch_size: 1
# timesteps (sequence length): 20
# features (embedding size): 16
# lstm output units: 8
# shape of input array: (1, 20, 16)
# shape of lstm output(return_sequences=False): (1, 8)
# shape of lstm output(return_sequences=True): (1, 20, 8)

# %%
import tensorflow as tf

# Hyperparameters
embedding_dim = 64
lstm1_dim = 64
lstm2_dim = 32
dense_dim = 64

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, embedding_dim),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm1_dim, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm2_dim)),
    tf.keras.layers.Dense(dense_dim, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 64)          523840
#
#  bidirectional_1 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 64)               41216
#  nal)
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 635,329
# Trainable params: 635,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set the training parameters
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
NUM_EPOCHS = 10

# Train the model
history = model.fit(train_dataset, epochs=NUM_EPOCHS, validation_data=test_dataset)
# Out:
# Epoch 1/10
# 98/98 [==============================] - 61s 540ms/step - loss: 0.6902 - accuracy: 0.5243 - val_loss: 0.6926 - val_accuracy: 0.5816
# Epoch 2/10
# 98/98 [==============================] - 48s 486ms/step - loss: 0.6774 - accuracy: 0.6143 - val_loss: 0.6517 - val_accuracy: 0.6272
# Epoch 3/10
# 98/98 [==============================] - 43s 439ms/step - loss: 0.5025 - accuracy: 0.7653 - val_loss: 0.5392 - val_accuracy: 0.7420
# Epoch 4/10
# 98/98 [==============================] - 41s 418ms/step - loss: 0.4388 - accuracy: 0.8068 - val_loss: 0.5543 - val_accuracy: 0.7529
# Epoch 5/10
# 98/98 [==============================] - 52s 532ms/step - loss: 0.4122 - accuracy: 0.8219 - val_loss: 0.4617 - val_accuracy: 0.7937
# Epoch 6/10
# 98/98 [==============================] - 41s 416ms/step - loss: 0.3333 - accuracy: 0.8648 - val_loss: 0.4427 - val_accuracy: 0.7973
# Epoch 7/10
# 98/98 [==============================] - 41s 413ms/step - loss: 0.2982 - accuracy: 0.8817 - val_loss: 0.4517 - val_accuracy: 0.8129
# Epoch 8/10
# 98/98 [==============================] - 42s 426ms/step - loss: 0.2670 - accuracy: 0.8976 - val_loss: 0.4134 - val_accuracy: 0.8241
# Epoch 9/10
# 98/98 [==============================] - 40s 411ms/step - loss: 0.3094 - accuracy: 0.8792 - val_loss: 0.4202 - val_accuracy: 0.8231
# Epoch 10/10
# 98/98 [==============================] - 41s 414ms/step - loss: 0.3202 - accuracy: 0.8750 - val_loss: 0.4259 - val_accuracy: 0.8214

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
